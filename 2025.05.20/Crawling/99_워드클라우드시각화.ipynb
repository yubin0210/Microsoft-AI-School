# %% [markdown]
# - https://drive.google.com/file/d/1todwi6NRInDwkFY24sSneP0c7RGTNTms/view?usp=sharing

# %% [markdown]
# #### konlpy 정상동작 확인

# %%
from konlpy.tag import Okt

okt = Okt()
print(okt.morphs("KoNLPy가 정상 설치되었는지 확인 중입니다."))
# Out:
# ['KoNLPy', '가', '정상', '설치', '되었는지', '확인', '중', '입니다', '.']

# %%
import jpype

if not jpype.isJVMStarted():
    jpype.startJVM()
print("JPype와 JVM이 정상 작동 중입니다.")
# Out:
# JPype와 JVM이 정상 작동 중입니다.

# %%
import pandas as pd

# %% [markdown]
# #### 데이터 준비

# %%
# ------------------------------
#   파일 경로
# ------------------------------
data_file = "../data/naver_comments_20250520_114641.csv"

# ------------------------------
#   불러올 컬럼명
# ------------------------------
col_name = "comment"

# ------------------------------
#   데이터 불러오기
# ------------------------------
data = pd.read_csv(data_file).loc[:, col_name].dropna()

# ------------------------------
#   내용 컬럼을 하나의 문장으로 합치기
# ------------------------------
text = " ".join(data)
text
# Out:
# '발볼이 넓은사람은 나이키가 불편해서 안신게됨 난 나이키만 신는데? 신발은 나이키 뉴발이 짱임 ㅎ.ㅎ 니는 언제 갔냐 어디 영포티들이나 스냅백쓰고 나이키 박스모아놓고 있지 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 돈 많으면 구찌, 발렌시아가 신고 저렴이 가성비 스포츠 브랜드 너무 많음. 솔직히 듣보 아니면 거기서 거기다. 단 한국인 특성상 발볼이 넓어 프로스펙스가 짱임 님들이 몰라서 그렇지 1980 대에는 나이키 아디다스 이런 브랜드하고 동급 경쟁을 하던 브랜드입니다뭐 나이키 아디다스 뉴발 하는데 다른 브랜드를 신어보지도 않고 오직 유행에만 따라가니 발이 힘들지요 나이키 망하는 이유 : PC 주의 나이키 아울렛 가면 대기표 막300번이런던데…..나이키 신고 뛰어보면 난 나이키가 젤 좋던데 신발은 니코보코가 대세 신발은 스베누지 명품이라 이제구하지도못함 돈이 없어서 못신겠지 ㅋㅋㅋ 신발은 프로 월드컵이지~!! 다른건 모르겠고 축구회는 라피도 히포 미만 잡이다 슈퍼카미트 미만잡! 죠다쉬 없나요? 히포가 진리임 뉴발은 진짜 한국인이 살린 브랜드고, 이랜드 그룹에서 한국에 억지 유행 안시켰으면, 그 다음해에 사업 접는 거 였음. 디자인으로 신는거지 발이 편하진않음 발이 더 편하거나 디자인이 좋거나 하는 신발들이 많아졌지 사실 경쟁력이 없잖아 뉴발란스가 확실히 편해요. 이번에 아디다스 삼바도 사봤는데 나이키보다는 편하더라고요. 나이키는 발볼이 너무 좁아요 ㅠㅠ 발볼이 너무좁다 허구한날 한정판이라고 콜라보네뭐네 출시소식만 주구장창 뿌리고 막상 매장가면 그림자구경도 못하는 신발들로 기만하더니 꼴좋타 ㅋㅋㅋ 잘나가던 시절에 충성 고객들이 나이가 들어버렸어...그러다 보니 브랜드도 같이 늙어버림 스케쳐스 한번 신어보세요. 착용감 최고고 디자인도 정말 굿이예요. 2개 있어요. 솔직히 나이키가 편하다고요..????진심 레알
낙 근본이라 또 몇년 지나면 다시 유행되겠지 돌고돌아 결국은 나이키.. 축구 국가대표 유니폼은 왜 아직도 나이키 인건지? 가격은 자꾸 오르는데 반해 내구성과 품질은 완전 싼마이 수준 특히 의류. 무조건 스케쳐스죠엄청편하고 디자인도 매번업그레이드 나이키 변화가 너무 느림 비싸고 편하지도 않음..다른 상품들도 많아서 선택폭이 넓어짐. 그냥 익숙해서 뉴발란스만 신어도 이랜드는 나이키 따라가지도 못함 이름값 못 하는 브랜드.내구성은 저질인데 A/S도 잘 안됨.신지않고 그냥 전시용신발 프로스펙스의 나라가 나이키를 걱정하네 디자인도 그렇지만 몇십만원주고산 신발이 3달도못신고 밑창 에어다터짐...실용성제로임... 내가 신는다. 나이키는 발볼이 넘 좁아서 불편해서 안 신 ...

# %% [markdown]
# #### 문자열 정제
#
# - 한글만 남기기

# %%
import re

clean_text = re.sub(r"[^가-힇\s]", " ", text)
clean_text
# Out:
# '발볼이 넓은사람은 나이키가 불편해서 안신게됨 난 나이키만 신는데  신발은 나이키 뉴발이 짱임     니는 언제 갔냐 어디 영포티들이나 스냅백쓰고 나이키 박스모아놓고 있지               돈 많으면 구찌  발렌시아가 신고 저렴이 가성비 스포츠 브랜드 너무 많음  솔직  듣보 아니면 거기서 거기다  단 한국인 특성상 발볼이 넓어 프로스펙스가 짱임 님들이 몰라서 그렇지      대에는 나이키 아디다스 이런 브랜드하고 동급 경쟁을 하던 브랜드입니다뭐 나이키 아디다스 뉴발 하는데 다른 브랜드를 신어보지도 않고 오직 유행에만 따라가니 발이  들지요 나이키 망하는 이유      주의 나이키 아울렛 가면 대기표 막   번이런던데   나이키 신고 뛰어보면 난 나이키가 젤 좋던데 신발은 니코보코가 대세 신발은 스베누지 명품이라 이제구하지도못함 돈이 없어서 못신겠지     신발은 프로 월드컵이지    다른건 모르겠고 축구회는 라피도  포 미만 잡이다 슈퍼카미트 미만잡  죠다쉬 없나요   포가 진리임 뉴발은 진짜 한국인이 살린 브랜드고  이랜드 그룹에서 한국에 억지 유행 안시켰으면  그 다음해에 사업 접는 거 였음  디자인으로 신는거지 발이 편하진않음 발이 더 편하거나 디자인이 좋거나 하는 신발들이 많아졌지 사실 경쟁력이 없잖아 뉴발란스가 확실  편해요  이번에 아디다스 삼바도 사봤는데 나이키보다는 편하더라고요  나이키는 발볼이 너무 좁아요    발볼이 너무좁다 허구한날 한정판이라고 콜라보네뭐네 출시소식만 주구장창 뿌리고 막상 매장가면 그림자구경도 못하는 신발들로 기만하더니 꼴좋타     잘나가던 시절에 충성 고객들이 나이가 들어버렸어   그러다 보니 브랜드도 같이 늙어버림 스케쳐스 한번 신어보세요  착용감 최고고 디자인도 정말 굿이예요   개 있어요  솔직  나이키가 편하다고요      진심 레알이세요    그똑같은 가격대로 아디다스 뉴발신는게 훨 더 편하지 아니 무슨 운동화를 칼발같이 만들어놨어 발볼에 맞춰서 심을려면 한치수 크게 사야하는데 그렇게 사면 뒷꿈치가 남음 그래서
# %% [markdown]
# - 블용어 사전

# %%
# -----------------------
# 외부 불용어 사전
# -----------------------

import requests

url = "https://raw.githubusercontent.com/stopwords-iso/stopwords-ko/refs/heads/master/stopwords-ko.txt"
response = requests.get(url)

# 줄 단위로 나누고, 공백 제거 후 리스트 생성
external_stopwords = [
    line.strip() for line in response.text.splitlines() if line.strip()
]

# -----------------------
# 커스터마이즈 불용어 사전
# -----------------------
custom_stopwords = ["나이키", "만원", "때문", "사실", "사람"]


# -----------------------
# 최종 불용어 사전
#   외부 불용어 사전, 커스터마이즈 불용어사전 합치고 중복 제거
# -----------------------
stopwords = set(external_stopwords + custom_stopwords)

# %% [markdown]
# #### 명사 추출 및 불용어 제거
#
# - KoNLPy라이브러리의 형태소분석기 사용
# - KoNLPy 사용 시 자바(JDK)가 필요할 수 있으니, 환경에 따라 JDK 설치 및 JAVA_HOME 환경변수 설정이 필요할 수도 있습니다​

# %%
# ----------------------------
# 형태소 분석기로 명사만 추출
# ----------------------------

from konlpy.tag import Okt

okt = Okt()
nouns = okt.nouns(clean_text)

# ----------------------------
# 한글자인 명사와 불용어 제거
# ----------------------------

filtered_nouns = [n for n in nouns if len(n) > 1 and n not in stopwords]

# %% [markdown]
# #### 단어 빈도 계산
#
# - 리스트에서 각 항목이 몇 번 나오는지 카운트

# %%
from collections import Counter

counter = Counter(filtered_nouns)  # 명사 리스트를 Counter 객체로 변환
print(counter.most_common(10))
# Out:
# [('신발', 114), ('디자인', 63), ('브랜드', 55), ('요즘', 49), ('아디다스', 46), ('가격', 42), ('발볼', 40), ('뉴발', 40), ('운동화', 34), ('신어', 31)]

# %% [markdown]
# #### 상위명사 추출

# %%
top50 = dict(
    counter.most_common(50)
)  # 가장 많이 등장한 50개 단어만 추출하여 딕셔너리 생성

# %% [markdown]
# #### 한글 폰트 설정 및 워드클라우드 시각화

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

font_path = (
    "/Library/Fonts/D2Coding-Ver1.3.2-20180524.ttc"  # 한글 폰트 경로 (환경에 맞게 변경)
)
wc = WordCloud(font_path=font_path, background_color="white", width=800, height=600)

# 앞서 계산한 단어 빈도 사용하여 워드클라우드 생성
cloud = wc.generate_from_frequencies(
    top50
)  # 또는 wc.generate_from_frequencies(counter) 전체 단어 사용

# 워드클라우드 이미지 시각화
plt.figure(figsize=(10, 8))
plt.imshow(cloud, interpolation="bilinear")
plt.axis("off")  # 축 제거
plt.show()

# %%
from matplotlib import font_manager

# 시스템에 설치된 모든 폰트 리스트 가져오기
font_list = font_manager.findSystemFonts(fontpaths=None, fontext="ttf")

# 한글 폰트만 필터링 (이름에 'Malgun', 'Gothic', 'Nanum', 'Apple' 등 포함)
korean_fonts = [
    f
    for f in font_list
    if "malgun" in f.lower()
    or "gothic" in f.lower()
    or "nanum" in f.lower()
    or "apple" in f.lower()
]

# 결과 확인
for font in korean_fonts:
    print(font)
