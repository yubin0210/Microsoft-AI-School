# %% [markdown]
# #### 웹페이지 요청 및 응답받기
# * `requests.get(url)`
#     *  -> Response 객체 리턴
# * Response  객체의 주요 속성
#     * `status_code` : 요청 성공 여부
#         * 200 : 요청이 성공적으로 처리됨
#         * 4XX : 클라이언트 오류
#             * 403 : 권한 없음
#             * 404 : Not Found(요청한 리소스를 찾을 수 없음)
#         * 5XX : 서버 오류
#             * 500 : 서버 내부 오류
#     * `text` : 응답 본문 (utf-8로 변환된 문자열 형태로 제공)
#     * `content` : 응답 본문 (byte형태로 제공)

# %%
# -----------------------------------------
# 웹페이지 요청 및 응답받기
# -----------------------------------------
import requests
url = 'https://finance.naver.com/news/mainnews.naver'
response = requests.get(url)

# -----------------------------------------
# 요청 성공여부 확인
# -----------------------------------------
status_code = response.status_code 

# -----------------------------------------
# 응답받은 웹문서
# -----------------------------------------
html = response.text

print(status_code)
html # ==> print(html)로 출력 시 vscode 다운될 수 있음
# Out:
# 200
# '<!--  global include -->\n\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\n\t\t\n\t\t\t\n\t\t\t\t<title>네이버페이 증권</title>\n\t\t\t\n\t\t\t\n\t\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버페이 증권" />\n\n\n\n\n\n\t\n    \n        <meta property="og:url" content="http://finance.naver.com/news/mainnews.naver"/>\n        \n\t\t\t\n\t\t    \n\t\t    \t<meta property="og:title" content="주요뉴스 : 네이버페이 증권"/>\n\t\t     \n\t\t\n\t\t\n\t\t\t\n\t\t\t   <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>\n\t\t    \n\t\t    \n\t\t\n\t\t \n\t\t\t\n\t\t\t    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t    \n\t\t    \n\t\t\n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버페이 증권"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/finance_header.css\'>\n\n\t\n\t\n\t\n\t\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/newstock.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/common.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/layout.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/main.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/newstock2.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/newstock3.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/world.css">\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/js/jindo.min.ns.1.5.3.euckr.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/js/release/common.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/js/jindoComponent/jindo.Component.1.0.3.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/js/nhn.autocomplete.stock.js"></script>\n\t\t\t\n\t\t\n\n\t\t\n\t\n\n<script>\n\tvar ieVersion = (function () {\n        var version = -1;\n        if (\n          navigator.appName == \'Microsoft Internet Explorer\' &&\n          navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1 &&\n          new RegExp(\'MSIE ([0-9]{1,}[\\./0-9]{0,})\').exec(navigator.userAgent) != null\n        ) {\n          version = parseInt(RegExp.$1);\n        }\n        return version;\n      })();\n</script>\n\t\n\n\t<link rel="shortcut icon" href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" type="image/x-icon">\n\t\n\t<script type="text/javascript">\n    (function(){\n\t\tdocument.write(\n\t\t\t\t[\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/imgstock/favi/favicon-180x180.png"/>\',\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>\',\n\t\t\t\t\t\'<link rel="icon" type="image/png" sizes="16x16" href="https://ssl.pstatic.net/imgstock/favi/favicon-16x ...

# %% [markdown]
# #### html문서에서 요소 추출
# * BeautisulSoup 객체 생성
#     * `BeautifulSoup(html문서, html파서)`
# * 요소 추출
#     * `select_one(선택자)`
#         * 선택자로 요소 1개 추출
#         * 동일한 선택자를 가진 요소가 여러개인 경우 가장 첫번째 요소만 추출
#     * `select(선택자)`
#         * 모든 요소를 리스트로 추출

# %%
# -----------------------------------------
# BeautifulSoup 객체 생성
# -----------------------------------------

from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')


# -----------------------------------------
# html 문서에서 뉴스 첫번째 뉴스 제목 추출하기
# -----------------------------------------
first_article = soup.select_one(".articleSubject > a")


# -----------------------------------------
# html 문서에서 뉴스 모든 뉴스 제목 추출하기
# -----------------------------------------
article_list = soup.select(".articleSubject > a")


print(first_article)
print(article_list)
# Out:
# <a href="/news/news_read.naver?article_id=0001882862&amp;office_id=057&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">[단독] 지반침하 두려움 큰데…사고위치 '지번' 돌연 숨긴 국토부</a>
# [<a href="/news/news_read.naver?article_id=0001882862&amp;office_id=057&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">[단독] 지반침하 두려움 큰데…사고위치 '지번' 돌연 숨긴 국토부</a>, <a href="/news/news_read.naver?article_id=0001206779&amp;office_id=215&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">관세 늪에 빠진 美 증시…"최악의 4월 향한다"</a>, <a href="/news/news_read.naver?article_id=0002949937&amp;office_id=029&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">"지금 투자 적기"… 외면 받았던 인도 ETF, 다시 자금 몰린다</a>, <a href="/news/news_read.naver?article_id=0002949936&amp;office_id=029&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1"> 트럼프 취임 100일도 안됐는데… `탈 미국·셀 USA` 가속[기획]</a>, <a href="/news/news_read.naver?article_id=0002949920&amp;office_id=029&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">中개미들의 애국 반란…`궈차오` 이어 `주식투자` 열풍</a>, <a href="/news/news_read.naver?article_id=0005339744&amp;office_id=014&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">'불닭 신화' 삼양식품 100만원 황제주 눈앞</a>, <a href="/news/news_read.naver?article_id=0005122601&amp;office_id=015&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">삼성·미래 'ETF 점유율 격차' 더 벌어졌다</a>, <a href="/news/news_read.naver?article_id=0000076806&amp;office_id=243&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">‘파월 때리기’에 뺨 맞는 달러…“금값만 신났네”</a>, <a href="/news/news_read.naver?article_id=0004477146&amp;office_id=011&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">“어차피 상폐에 한탕?”…감자·유증·CB 남발 코스닥사, ‘먹튀’ 빨간불</a>, <a href="/news/news_read.naver?article_id=0005480750&amp;office_id=009&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">증시 거래 터졌지만…정치테마株만 춤췄다</a>, <a href="/news/news_read.naver?article_id=0005480748&amp;office_id=009&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">대선 쟁점된 '자사주 소각'…지주사株 뜰까</a>, <a href="/news/news_read.naver?article_id=0004477134&amp;office_id=011&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">'10조 매도폭탄' 外人, 에이비엘·펩트론 등 코스닥 바이오주엔 베팅</a>, <a href="/news/news_read.naver?article_id=0004477130&amp;office_id=011&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">美 편의점주, MSCI 편입 전망되는데…국내는 울상</a>, <a href="/news/news_read.naver?article_id=0005480712&amp;office_id=009&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">金 '신고가'·구리는 '미끌'… 엇갈린 원자재</a>, <a href="/news/news_read.naver?article_id=0004477096&amp;office_id=011&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1"> AMEXIT[투자의 창]</a>, <a href="/news/news_read.naver?article_id=0004477094&amp;office_id=011&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">글로벌 분산투자 ETF, 관세쇼크에 '피난처'로 뜬다</a>, <a href="/news/news_read.naver?article_id=0001206764&amp;office_id=215&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">한국 비중 20년새 반토막...중국은 4배로</a>, <a href="/news/news_read.naver?article_id=0001206760&amp;office_id=215&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">위축되는 투심…"이번주가 고비" [박해린의 마켓톡톡]</a>, <a href="/news/news_read.naver?article_id=0001206759&amp;office_id=215&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">"올해 44% 떨어졌는데"…'신차 연기'로 더 불안하네</a>, <a href="/news/news_read.naver?article_id=0000076804&amp;office_id=243&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">포브스 회장, '인플레 악몽' 경고…"연준은 뭘 몰라"</a>]

# %% [markdown]
# #### 요소에서 원하는 부분 추출
# * `text`
#     * 요소의 텍스트 추출
# * `attrs["속성명"]`
#     * 특정 속성 추출

# %%
first_article
# Out:
# <a href="/news/news_read.naver?article_id=0001882862&amp;office_id=057&amp;mode=mainnews&amp;type=&amp;date=2025-04-22&amp;page=1">[단독] 지반침하 두려움 큰데…사고위치 '지번' 돌연 숨긴 국토부</a>

# %%
first_article.text
# Out:
# "[단독] 지반침하 두려움 큰데…사고위치 '지번' 돌연 숨긴 국토부"

# %%
first_article.attrs
# Out:
# {'href': '/news/news_read.naver?article_id=0001882862&office_id=057&mode=mainnews&type=&date=2025-04-22&page=1'}

# %%
first_article.attrs["href"]
# Out:
# '/news/news_read.naver?article_id=0001882862&office_id=057&mode=mainnews&type=&date=2025-04-22&page=1'
