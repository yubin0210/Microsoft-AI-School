# %%
import os, sys
print(os.getcwd())
current_dir = os.path.dirname(os.getcwd())
print(current_dir)
os.chdir(current_dir)
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/el203/code/Users/el20/DL/ch06
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/el203/code/Users/el20/DL
# train loss:2.300189170091009
# === epoch:1, train acc:0.274, test acc:0.332 ===
# train loss:2.2975507244425755
# train loss:2.2934931404128793
# train loss:2.290047611405878
# train loss:2.28187880150894
# train loss:2.271080143550925
# train loss:2.2653645571617376
# train loss:2.246226288241439
# train loss:2.2341937139048413
# train loss:2.2031497526114268
# train loss:2.1819898569381007
# train loss:2.114429604559547
# train loss:2.09700853368044
# train loss:2.0508509180659056
# train loss:2.0040073512942342
# train loss:1.9627260548615513
# train loss:1.8499852871897817
# train loss:1.8269572060849595
# train loss:1.7740605815663395
# train loss:1.6936772367115547
# train loss:1.6572552732605472
# train loss:1.5884796291156347
# train loss:1.450268322065709
# train loss:1.379895156141842
# train loss:1.3703143346373066
# ...
