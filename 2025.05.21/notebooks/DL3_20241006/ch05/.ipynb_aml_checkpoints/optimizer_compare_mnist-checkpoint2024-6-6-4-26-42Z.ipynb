# %%
import os, sys
print(os.getcwd())
current_dir = os.path.dirname(os.getcwd())
print(current_dir)
os.chdir(current_dir)
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/el202/code/Users/el20/DL/ch05
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/el202/code/Users/el20/DL
# ===========iteration:0===========
# SGD:2.341240874237441
# Momentum:2.327546644501086
# AdaGrad:2.124548781311642
# Adam:2.234172130805735
# ===========iteration:100===========
# SGD:1.4140938816064943
# Momentum:0.2968769104014255
# AdaGrad:0.10398888615929425
# Adam:0.22577810252944536
# ===========iteration:200===========
# SGD:0.7422874591965606
# Momentum:0.30771271247734555
# AdaGrad:0.11290221628384695
# Adam:0.14570747011634544
# ===========iteration:300===========
# SGD:0.4714003728573841
# Momentum:0.1931845165394349
# AdaGrad:0.07150559955212148
# Adam:0.11382231491414818
# ===========iteration:400===========
# SGD:0.3672113209692537
# Momentum:0.189147252154799
# AdaGrad:0.05317850278324343
# Adam:0.14920375320667167
# ===========iteration:500===========
# SGD:0.3810742792156322
# Momentum:0.1327521873849011
# ...
